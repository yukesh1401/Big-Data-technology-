# %%
# ============================================================
# 🧩 Step 1: Install Java and Apache Pig
# ============================================================

# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/pig/pig-0.17.0/pig-0.17.0.tar.gz
# !tar -xzf pig-0.17.0.tar.gz
# !mv pig-0.17.0 /usr/local/pig

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["PIG_HOME"] = "/usr/local/pig"
os.environ["PATH"] += ":/usr/local/pig/bin"

# %%
# ============================================================
# 📄 Step 2: Create Sample Employee Data
# ============================================================

data = """1,Arun,IT,35000
2,Bala,HR,28000
3,Kiran,IT,42000
4,Sara,Finance,39000
5,Devi,HR,31000
6,Ram,Finance,45000
"""

with open("/content/employee.txt", "w") as f:
    f.write(data)

# !cat /content/employee.txt
# Out:
# 1,Arun,IT,35000
# 2,Bala,HR,28000
# 3,Kiran,IT,42000
# 4,Sara,Finance,39000
# 5,Devi,HR,31000
# 6,Ram,Finance,45000

# %%
# ============================================================
# 🚀 Step 4: Run Pig Script Locally
# ============================================================

# !pig -x local /content/experiment5.pig
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.hadoop.security.authentication.util.KerberosUtil (file:/usr/local/pig/lib/hadoop2-runtime/hadoop-auth-2.7.3.jar) to method sun.security.krb5.Config.getInstance()
# WARNING: Please consider reporting this to the maintainers of org.apache.hadoop.security.authentication.util.KerberosUtil
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 2025-11-11 14:54:17,903 INFO  [main] pig.ExecTypeProvider (ExecTypeProvider.java:selectExecType(41)) - Trying ExecType : LOCAL
# 2025-11-11 14:54:17,905 INFO  [main] pig.ExecTypeProvider (ExecTypeProvider.java:selectExecType(43)) - Picked LOCAL as the ExecType
# 2025-11-11 14:54:17,948 [main] INFO  org.apache.pig.Main - Apache Pig version 0.17.0 (r1797386) compiled Jun 02 2017, 15:41:58
# 2025-11-11 14:54:17,949 [main] INFO  org.apache.pig.Main - Logging error messages to: /content/pig_1762872857942.log
# 2025-11-11 14:54:17,964 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - user.name is deprecated. Instead, use mapreduce.job.user.name
# 2025-11-11 14:54:18,343 [main] ERROR org.apache.pig.Main - ERROR 2997: Encountered IOException. File /content/experiment5.pig does not exist
# Details at logfile: /content/pig_1762872857942.log
# 2025-11-11 14:54:18,367 [main] INFO  org.apache.pig.Main - Pig script completed in 966 milliseconds (966 ms)

# %%
# %%writefile /content/experiment5.pig
# emp_data = LOAD '/content/employee.txt' USING PigStorage(',')
#             AS (id:int, name:chararray, dept:chararray, salary:int);
#
# grouped = GROUP emp_data BY dept;
# avg_salary = FOREACH grouped GENERATE group, AVG(emp_data.salary);
#
# STORE avg_salary INTO '/content/output_pig' USING PigStorage(',');
# Out:
# Writing /content/experiment5.pig

# %%
# !rm -rf /content/output_pig
# !pig -x local /content/experiment5.pig
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.hadoop.security.authentication.util.KerberosUtil (file:/usr/local/pig/lib/hadoop2-runtime/hadoop-auth-2.7.3.jar) to method sun.security.krb5.Config.getInstance()
# WARNING: Please consider reporting this to the maintainers of org.apache.hadoop.security.authentication.util.KerberosUtil
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 2025-11-11 14:57:06,949 INFO  [main] pig.ExecTypeProvider (ExecTypeProvider.java:selectExecType(41)) - Trying ExecType : LOCAL
# 2025-11-11 14:57:06,952 INFO  [main] pig.ExecTypeProvider (ExecTypeProvider.java:selectExecType(43)) - Picked LOCAL as the ExecType
# 2025-11-11 14:57:07,002 [main] INFO  org.apache.pig.Main - Apache Pig version 0.17.0 (r1797386) compiled Jun 02 2017, 15:41:58
# 2025-11-11 14:57:07,002 [main] INFO  org.apache.pig.Main - Logging error messages to: /content/pig_1762873026996.log
# 2025-11-11 14:57:07,018 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - user.name is deprecated. Instead, use mapreduce.job.user.name
# 2025-11-11 14:57:07,378 [main] INFO  org.apache.pig.impl.util.Utils - Default bootup file /root/.pigbootup not found
# 2025-11-11 14:57:07,554 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2025-11-11 14:57:07,556 [main] INFO  org.apache.pig.backend.hadoop.executionengine.HExecutionEngine - Connecting to hadoop file system at: file:///
# 2025-11-11 14:57:07,583 [main] INFO  org.apache.pig.PigServer - Pig Script ID for the session: PIG-experiment5.pig-99e812bb-fd70-46a1-97ca-5c10728e23e9
# 2025-11-11 14:57:07,583 [main] WARN  org.apache.pig.PigServer - ATS is disabled since yarn.timeline-service.enabled set to false
# 2025-11-11 14:57:08,029 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2025-11-11 14:57:08,048 [main] INFO  org.apache.pig.tools.pigstats.ScriptState - Pig features used in the script: GROUP_BY
# 2025-11-11 14:57:08,104 [main] INFO  org.apache.pig.newplan.logical.optimizer.LogicalPlanOptimizer - {RULES_ENABLED=[AddForEach, ColumnMapKeyPrune, ConstantCalculator, GroupByConstParallelSetter, LimitOptimizer, LoadTypeCastInserter, MergeFilter, MergeForEach, NestedLimitOptimizer, PartitionFilterOptimizer, PredicatePushdownOptimizer, PushDownForEachFlatten, PushUpFilter, SplitFilter, StreamTypeCastInserter]}
# 2025-11-11 14:57:08,148 [main] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2025-11-11 14:57:08,216 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler - File concatenation threshold: 100 optimistic? false
# 2025-11-11 14:57:08,226 [main] INFO  org.apache.pig.backend.hadoop.executionengine.util.CombinerOptimizerUtil - Choosing to move algebraic foreach to combiner
# 2025-11-11 14:57:08,245 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MultiQueryOptimizer - MR plan size before optimization: 1
# 2025-11-11 14:57:08,245 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MultiQueryOptimizer - MR plan size after optimization: 1
# 2025-11-11 14:57:08,285 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - session.id is deprecated. Instead, use dfs.metrics.session-id
# 2025-11-11 14:57:08,286 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Initializing JVM Metrics with processName=JobTracker, sessionId=
# 2025-11-11 14:57:08,316 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState - Pig script settings are added to the job
# 2025-11-11 14:57:08,322 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2025-11-11 14:57:08,323 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3
# 2025-11-11 14:57:08,325 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.output.compress is deprecated. Instead, use mapreduce.output.fileoutputformat.compress
# 2025-11-11 14:57:08,328 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Reduce phase detected, estimating # of required reducers.
# 2025-11-11 14:57:08,328 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Using reducer estimator: org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator
# 2025-11-11 14:57:08,332 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator - BytesPerReducer=1000000000 maxReducers=999 totalInputFileSize=106
# 2025-11-11 14:57:08,332 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting Parallelism to 1
# 2025-11-11 14:57:08,332 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2025-11-11 14:57:08,344 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting up single store job
# 2025-11-11 14:57:08,350 [main] INFO  org.apache.pig.data.SchemaTupleFrontend - Key [pig.schematuple] is false, will not generate code.
# 2025-11-11 14:57:08,350 [main] INFO  org.apache.pig.data.SchemaTupleFrontend - Starting process to move generated code to distributed cacche
# 2025-11-11 14:57:08,350 [main] INFO  org.apache.pig.data.SchemaTupleFrontend - Distributed cache not supported or needed in local mode. Setting key [pig.schematuple.local.dir] with code temp directory: /tmp/1762873028349-0
# 2025-11-11 14:57:08,445 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 1 map-reduce job(s) waiting for submission.
# 2025-11-11 14:57:08,446 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker.http.address is deprecated. Instead, use mapreduce.jobtracker.http.address
# 2025-11-11 14:57:08,454 [JobControl] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2025-11-11 14:57:08,471 [JobControl] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2025-11-11 14:57:08,480 [JobControl] WARN  org.apache.hadoop.util.NativeCodeLoader - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2025-11-11 14:57:08,540 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2025-11-11 14:57:08,548 [JobControl] INFO  org.apache.pig.builtin.PigStorage - Using PigTextInputFormat
# 2025-11-11 14:57:08,551 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input paths to process : 1
# 2025-11-11 14:57:08,551 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths to process : 1
# 2025-11-11 14:57:08,576 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths (combined) to process : 1
# 2025-11-11 14:57:08,637 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2025-11-11 14:57:08,844 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_local529428745_0001
# 2025-11-11 14:57:08,985 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://localhost:8080/
# 2025-11-11 14:57:08,986 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - HadoopJobId: job_local529428745_0001
# 2025-11-11 14:57:08,986 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Processing aliases avg_salary,emp_data,grouped
# 2025-11-11 14:57:08,986 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - detailed locations: M: emp_data[1,11],emp_data[-1,-1],avg_salary[5,13],grouped[4,10] C: avg_salary[5,13],grouped[4,10] R: avg_salary[5,13]
# 2025-11-11 14:57:08,988 [Thread-18] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter set in config null
# 2025-11-11 14:57:09,006 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 0% complete
# 2025-11-11 14:57:09,006 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Running jobs are [job_local529428745_0001]
# 2025-11-11 14:57:09,013 [Thread-18] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2025-11-11 14:57:09,016 [Thread-18] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2025-11-11 14:57:09,016 [Thread-18] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2025-11-11 14:57:09,017 [Thread-18] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2025-11-11 14:57:09,020 [Thread-18] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2025-11-11 14:57:09,021 [Thread-18] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter is org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigOutputCommitter
# 2025-11-11 14:57:09,065 [Thread-18] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for map tasks
# 2025-11-11 14:57:09,068 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local529428745_0001_m_000000_0
# 2025-11-11 14:57:09,122 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2025-11-11 14:57:09,141 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2025-11-11 14:57:09,148 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Processing split: Number of splits :1
# Total Length = 106
# Input split[0]:
#    Length = 106
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2025-11-11 14:57:09,157 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.builtin.PigStorage - Using PigTextInputFormat
# 2025-11-11 14:57:09,160 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigRecordReader - Current split being processed file:/content/employee.txt:0+106
# 2025-11-11 14:57:09,241 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - (EQUATOR) 0 kvi 26214396(104857584)
# 2025-11-11 14:57:09,241 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - mapreduce.task.io.sort.mb: 100
# 2025-11-11 14:57:09,242 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - soft limit at 83886080
# 2025-11-11 14:57:09,242 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufvoid = 104857600
# 2025-11-11 14:57:09,242 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396; length = 6553600
# 2025-11-11 14:57:09,250 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2025-11-11 14:57:09,262 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2025-11-11 14:57:09,264 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.data.SchemaTupleBackend - Key [pig.schematuple] was not set... will not generate code.
# 2025-11-11 14:57:09,306 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigGenericMapReduce$Map - Aliases being processed per job phase (AliasName[line,offset]): M: emp_data[1,11],emp_data[-1,-1],avg_salary[5,13],grouped[4,10] C: avg_salary[5,13],grouped[4,10] R: avg_salary[5,13]
# 2025-11-11 14:57:09,319 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2025-11-11 14:57:09,319 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Starting flush of map output
# 2025-11-11 14:57:09,319 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Spilling map output
# 2025-11-11 14:57:09,320 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufend = 96; bufvoid = 104857600
# 2025-11-11 14:57:09,320 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396(104857584); kvend = 26214376(104857504); length = 21/6553600
# 2025-11-11 14:57:09,357 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigCombiner$Combine - Aliases being processed per job phase (AliasName[line,offset]): M: emp_data[1,11],emp_data[-1,-1],avg_salary[5,13],grouped[4,10] C: avg_salary[5,13],grouped[4,10] R: avg_salary[5,13]
# 2025-11-11 14:57:09,364 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Finished spill 0
# 2025-11-11 14:57:09,370 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local529428745_0001_m_000000_0 is done. And is in the process of committing
# 2025-11-11 14:57:09,378 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2025-11-11 14:57:09,378 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local529428745_0001_m_000000_0' done.
# 2025-11-11 14:57:09,378 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local529428745_0001_m_000000_0
# 2025-11-11 14:57:09,379 [Thread-18] INFO  org.apache.hadoop.mapred.LocalJobRunner - map task executor complete.
# 2025-11-11 14:57:09,382 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local529428745_0001_r_000000_0
# 2025-11-11 14:57:09,384 [Thread-18] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for reduce tasks
# 2025-11-11 14:57:09,399 [pool-3-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2025-11-11 14:57:09,403 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2025-11-11 14:57:09,405 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.ReduceTask - Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@6fb38aaf
# 2025-11-11 14:57:09,416 [pool-3-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - MergerManager: memoryLimit=734003200, maxSingleShuffleLimit=183500800, mergeThreshold=484442144, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2025-11-11 14:57:09,420 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - attempt_local529428745_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2025-11-11 14:57:09,477 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher - localfetcher#1 about to shuffle output of map attempt_local529428745_0001_m_000000_0 decomp: 61 len: 65 to MEMORY
# 2025-11-11 14:57:09,482 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput - Read 61 bytes from map-output for attempt_local529428745_0001_m_000000_0
# 2025-11-11 14:57:09,483 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - closeInMemoryFile -> map-output of size: 61, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->61
# 2025-11-11 14:57:09,486 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - EventFetcher is interrupted.. Returning
# 2025-11-11 14:57:09,488 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2025-11-11 14:57:09,488 [pool-3-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2025-11-11 14:57:09,494 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2025-11-11 14:57:09,494 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 54 bytes
# 2025-11-11 14:57:09,495 [pool-3-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merged 1 segments, 61 bytes to disk to satisfy reduce memory limit
# 2025-11-11 14:57:09,496 [pool-3-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 1 files, 65 bytes from disk
# 2025-11-11 14:57:09,496 [pool-3-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 0 segments, 0 bytes from memory into reduce
# 2025-11-11 14:57:09,497 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2025-11-11 14:57:09,497 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 54 bytes
# 2025-11-11 14:57:09,499 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2025-11-11 14:57:09,507 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 50% complete
# 2025-11-11 14:57:09,507 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Running jobs are [job_local529428745_0001]
# 2025-11-11 14:57:09,507 [pool-3-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 1
# 2025-11-11 14:57:09,519 [pool-3-thread-1] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2025-11-11 14:57:09,520 [pool-3-thread-1] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2025-11-11 14:57:09,520 [pool-3-thread-1] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2025-11-11 14:57:09,528 [pool-3-thread-1] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigMapReduce$Reduce - Aliases being processed per job phase (AliasName[line,offset]): M: emp_data[1,11],emp_data[-1,-1],avg_salary[5,13],grouped[4,10] C: avg_salary[5,13],grouped[4,10] R: avg_salary[5,13]
# 2025-11-11 14:57:09,532 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local529428745_0001_r_000000_0 is done. And is in the process of committing
# 2025-11-11 14:57:09,538 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2025-11-11 14:57:09,538 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.Task - Task attempt_local529428745_0001_r_000000_0 is allowed to commit now
# 2025-11-11 14:57:09,542 [pool-3-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt_local529428745_0001_r_000000_0' to file:/content/output_pig/_temporary/0/task_local529428745_0001_r_000000
# 2025-11-11 14:57:09,544 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce > reduce
# 2025-11-11 14:57:09,544 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local529428745_0001_r_000000_0' done.
# 2025-11-11 14:57:09,544 [pool-3-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local529428745_0001_r_000000_0
# 2025-11-11 14:57:09,544 [Thread-18] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce task executor complete.
# 2025-11-11 14:57:09,750 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2025-11-11 14:57:09,759 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2025-11-11 14:57:09,759 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2025-11-11 14:57:09,760 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2025-11-11 14:57:09,790 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 100% complete
# 2025-11-11 14:57:09,791 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.SimplePigStats - Script Statistics:
#
# HadoopVersion	PigVersion	UserId	StartedAt	FinishedAt	Features
# 2.7.3	0.17.0	root	2025-11-11 14:57:08	2025-11-11 14:57:09	GROUP_BY
#
# Success!
#
# Job Stats (time in seconds):
# JobId	Maps	Reduces	MaxMapTime	MinMapTime	AvgMapTime	MedianMapTime	MaxReduceTime	MinReduceTime	AvgReduceTime	MedianReducetime	Alias	Feature	Outputs
# job_local529428745_0001	1	1	n/a	n/a	n/a	n/a	n/a	n/a	n/a	n/a	avg_salary,emp_data,grouped	GROUP_BY,COMBINER	/content/output_pig,
#
# Input(s):
# Successfully read 6 records from: "/content/employee.txt"
#
# Output(s):
# Successfully stored 3 records in: "/content/output_pig"
#
# Counters:
# Total records written : 3
# Total bytes written : 0
# Spillable Memory Manager spill count : 0
# Total bags proactively spilled: 0
# Total records proactively spilled: 0
#
# Job DAG:
# job_local529428745_0001
#
#
# 2025-11-11 14:57:09,795 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2025-11-11 14:57:09,798 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2025-11-11 14:57:09,799 [main] INFO  org.apache.hadoop.metrics.jvm.JvmMetrics - Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 2025-11-11 14:57:09,814 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Success!
# 2025-11-11 14:57:09,832 [main] INFO  org.apache.pig.Main - Pig script completed in 3 seconds and 408 milliseconds (3408 ms)

# %%
# !cat /content/output_pig/part-r-00000
# Out:
# HR,29500.0
# IT,38500.0
# Finance,42000.0
