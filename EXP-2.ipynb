# %%
# =============================
# 🧩 STEP 1: Install Java
# =============================
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null

# =============================
# 🧩 STEP 2: Download & Setup Hadoop 3.3
# =============================
# !wget -q https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# !tar -xzf hadoop-3.3.6.tar.gz
# !mv hadoop-3.3.6 /usr/local/hadoop

# =============================
# 🧩 STEP 3: Configure Environment Variables
# =============================
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["HADOOP_HOME"] = "/usr/local/hadoop"
os.environ["PATH"] = f"{os.environ['HADOOP_HOME']}/bin:{os.environ['JAVA_HOME']}/bin:" + os.environ["PATH"]

# Verify versions
# !java -version
# !hadoop version
# Out:
# openjdk version "11.0.28" 2025-07-15
# OpenJDK Runtime Environment (build 11.0.28+6-post-Ubuntu-1ubuntu122.04.1)
# OpenJDK 64-Bit Server VM (build 11.0.28+6-post-Ubuntu-1ubuntu122.04.1, mixed mode, sharing)
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /usr/local/hadoop/share/hadoop/common/hadoop-common-3.3.6.jar

# %%
# Format namenode
# !hdfs namenode -format
# Out:
# WARNING: /usr/local/hadoop/logs does not exist. Creating.
# 2025-11-11 15:17:26,372 INFO namenode.NameNode: STARTUP_MSG:
# /************************************************************
# STARTUP_MSG: Starting NameNode
# STARTUP_MSG:   host = 7dc7ebdfbbd2/172.28.0.12
# STARTUP_MSG:   args = [-format]
# STARTUP_MSG:   version = 3.3.6
# STARTUP_MSG:   classpath = /usr/local/hadoop/etc/hadoop:/usr/local/hadoop/share/hadoop/common/lib/netty-resolver-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-transport-classes-epoll-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-codec-socks-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-beanutils-1.9.4.jar:/usr/local/hadoop/share/hadoop/common/lib/kerby-config-1.0.1.jar:/usr/local/hadoop/share/hadoop/common/lib/kerb-identity-1.0.1.jar:/usr/local/hadoop/share/hadoop/common/lib/jetty-security-9.4.51.v20230217.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-all-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/jaxb-impl-2.2.3-1.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-handler-proxy-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-resolver-dns-native-macos-4.1.89.Final-osx-x86_64.jar:/usr/local/hadoop/share/hadoop/common/lib/metrics-core-3.2.4.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-compress-1.21.jar:/usr/local/hadoop/share/hadoop/common/lib/jcip-annotations-1.0-1.jar:/usr/local/hadoop/share/hadoop/common/lib/javax.servlet-api-3.1.0.jar:/usr/local/hadoop/share/hadoop/common/lib/hadoop-auth-3.3.6.jar:/usr/local/hadoop/share/hadoop/common/lib/curator-framework-5.2.0.jar:/usr/local/hadoop/share/hadoop/common/lib/gson-2.9.0.jar:/usr/local/hadoop/share/hadoop/common/lib/jersey-servlet-1.19.4.jar:/usr/local/hadoop/share/hadoop/common/lib/snappy-java-1.1.8.2.jar:/usr/local/hadoop/share/hadoop/common/lib/kerby-asn1-1.0.1.jar:/usr/local/hadoop/share/hadoop/common/lib/httpcore-4.4.13.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-math3-3.1.1.jar:/usr/local/hadoop/share/hadoop/common/lib/slf4j-api-1.7.36.jar:/usr/local/hadoop/share/hadoop/common/lib/kerby-pkix-1.0.1.jar:/usr/local/hadoop/share/hadoop/common/lib/kerb-server-1.0.1.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-buffer-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-transport-native-epoll-4.1.89.Final-linux-x86_64.jar:/usr/local/hadoop/share/hadoop/common/lib/jul-to-slf4j-1.7.36.jar:/usr/local/hadoop/share/hadoop/common/lib/failureaccess-1.0.jar:/usr/local/hadoop/share/hadoop/common/lib/jsr311-api-1.1.1.jar:/usr/local/hadoop/share/hadoop/common/lib/jetty-http-9.4.51.v20230217.jar:/usr/local/hadoop/share/hadoop/common/lib/hadoop-shaded-guava-1.1.1.jar:/usr/local/hadoop/share/hadoop/common/lib/jetty-servlet-9.4.51.v20230217.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-handler-ssl-ocsp-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-io-2.8.0.jar:/usr/local/hadoop/share/hadoop/common/lib/jersey-server-1.19.4.jar:/usr/local/hadoop/share/hadoop/common/lib/jersey-json-1.20.jar:/usr/local/hadoop/share/hadoop/common/lib/listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar:/usr/local/hadoop/share/hadoop/common/lib/avro-1.7.7.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-text-1.10.0.jar:/usr/local/hadoop/share/hadoop/common/lib/kerby-util-1.0.1.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-logging-1.1.3.jar:/usr/local/hadoop/share/hadoop/common/lib/jackson-mapper-asl-1.9.13.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-configuration2-2.8.0.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-transport-native-epoll-4.1.89.Final-linux-aarch_64.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-collections-3.2.2.jar:/usr/local/hadoop/share/hadoop/common/lib/hadoop-shaded-protobuf_3_7-1.1.1.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-resolver-dns-native-macos-4.1.89.Final-osx-aarch_64.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-transport-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-codec-dns-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/jetty-io-9.4.51.v20230217.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-lang3-3.12.0.jar:/usr/local/hadoop/share/hadoop/common/lib/jersey-core-1.19.4.jar:/usr/local/hadoop/share/hadoop/common/lib/reload4j- ...
# STARTUP_MSG:   build = https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c; compiled by 'ubuntu' on 2023-06-18T08:22Z
# STARTUP_MSG:   java = 11.0.28
# ************************************************************/
# 2025-11-11 15:17:26,445 INFO namenode.NameNode: registered UNIX signal handlers for [TERM, HUP, INT]
# 2025-11-11 15:17:26,668 INFO namenode.NameNode: createNameNode [-format]
# 2025-11-11 15:17:27,555 INFO namenode.NameNode: Formatting using clusterid: CID-87819084-aaf5-4a12-bb9a-e3a11874b13e
# 2025-11-11 15:17:27,616 INFO namenode.FSEditLog: Edit logging is async:true
# 2025-11-11 15:17:27,684 INFO namenode.FSNamesystem: KeyProvider: null
# 2025-11-11 15:17:27,687 INFO namenode.FSNamesystem: fsLock is fair: true
# 2025-11-11 15:17:27,687 INFO namenode.FSNamesystem: Detailed lock hold time metrics enabled: false
# 2025-11-11 15:17:27,725 INFO namenode.FSNamesystem: fsOwner                = root (auth:SIMPLE)
# 2025-11-11 15:17:27,725 INFO namenode.FSNamesystem: supergroup             = supergroup
# 2025-11-11 15:17:27,725 INFO namenode.FSNamesystem: isPermissionEnabled    = true
# 2025-11-11 15:17:27,725 INFO namenode.FSNamesystem: isStoragePolicyEnabled = true
# 2025-11-11 15:17:27,725 INFO namenode.FSNamesystem: HA Enabled: false
# 2025-11-11 15:17:27,805 INFO common.Util: dfs.datanode.fileio.profiling.sampling.percentage set to 0. Disabling file IO profiling
# 2025-11-11 15:17:28,078 INFO blockmanagement.DatanodeManager: dfs.block.invalidate.limit : configured=1000, counted=60, effected=1000
# 2025-11-11 15:17:28,078 INFO blockmanagement.DatanodeManager: dfs.namenode.datanode.registration.ip-hostname-check=true
# 2025-11-11 15:17:28,083 INFO blockmanagement.BlockManager: dfs.namenode.startup.delay.block.deletion.sec is set to 000:00:00:00.000
# 2025-11-11 15:17:28,083 INFO blockmanagement.BlockManager: The block deletion will start around 2025 Nov 11 15:17:28
# 2025-11-11 15:17:28,086 INFO util.GSet: Computing capacity for map BlocksMap
# 2025-11-11 15:17:28,086 INFO util.GSet: VM type       = 64-bit
# 2025-11-11 15:17:28,088 INFO util.GSet: 2.0% max memory 3.2 GB = 64.9 MB
# 2025-11-11 15:17:28,088 INFO util.GSet: capacity      = 2^23 = 8388608 entries
# 2025-11-11 15:17:28,120 INFO blockmanagement.BlockManager: Storage policy satisfier is disabled
# 2025-11-11 15:17:28,120 INFO blockmanagement.BlockManager: dfs.block.access.token.enable = false
# 2025-11-11 15:17:28,128 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.threshold-pct = 0.999
# 2025-11-11 15:17:28,128 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.min.datanodes = 0
# 2025-11-11 15:17:28,128 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.extension = 30000
# 2025-11-11 15:17:28,129 INFO blockmanagement.BlockManager: defaultReplication         = 3
# 2025-11-11 15:17:28,129 INFO blockmanagement.BlockManager: maxReplication             = 512
# 2025-11-11 15:17:28,129 INFO blockmanagement.BlockManager: minReplication             = 1
# 2025-11-11 15:17:28,129 INFO blockmanagement.BlockManager: maxReplicationStreams      = 2
# 2025-11-11 15:17:28,129 INFO blockmanagement.BlockManager: redundancyRecheckInterval  = 3000ms
# 2025-11-11 15:17:28,129 INFO blockmanagement.BlockManager: encryptDataTransfer        = false
# 2025-11-11 15:17:28,129 INFO blockmanagement.BlockManager: maxNumBlocksToLog          = 1000
# 2025-11-11 15:17:28,177 INFO namenode.FSDirectory: GLOBAL serial map: bits=29 maxEntries=536870911
# 2025-11-11 15:17:28,177 INFO namenode.FSDirectory: USER serial map: bits=24 maxEntries=16777215
# 2025-11-11 15:17:28,177 INFO namenode.FSDirectory: GROUP serial map: bits=24 maxEntries=16777215
# 2025-11-11 15:17:28,177 INFO namenode.FSDirectory: XATTR serial map: bits=24 maxEntries=16777215
# 2025-11-11 15:17:28,196 INFO util.GSet: Computing capacity for map INodeMap
# 2025-11-11 15:17:28,196 INFO util.GSet: VM type       = 64-bit
# 2025-11-11 15:17:28,197 INFO util.GSet: 1.0% max memory 3.2 GB = 32.4 MB
# 2025-11-11 15:17:28,197 INFO util.GSet: capacity      = 2^22 = 4194304 entries
# 2025-11-11 15:17:28,210 INFO namenode.FSDirectory: ACLs enabled? true
# 2025-11-11 15:17:28,210 INFO namenode.FSDirectory: POSIX ACL inheritance enabled? true
# 2025-11-11 15:17:28,211 INFO namenode.FSDirectory: XAttrs enabled? true
# 2025-11-11 15:17:28,211 INFO namenode.NameNode: Caching file names occurring more than 10 times
# 2025-11-11 15:17:28,219 INFO snapshot.SnapshotManager: Loaded config captureOpenFiles: false, skipCaptureAccessTimeOnlyChange: false, snapshotDiffAllowSnapRootDescendant: true, maxSnapshotLimit: 65536
# 2025-11-11 15:17:28,221 INFO snapshot.SnapshotManager: SkipList is disabled
# 2025-11-11 15:17:28,228 INFO util.GSet: Computing capacity for map cachedBlocks
# 2025-11-11 15:17:28,228 INFO util.GSet: VM type       = 64-bit
# 2025-11-11 15:17:28,229 INFO util.GSet: 0.25% max memory 3.2 GB = 8.1 MB
# 2025-11-11 15:17:28,229 INFO util.GSet: capacity      = 2^20 = 1048576 entries
# 2025-11-11 15:17:28,244 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.window.num.buckets = 10
# 2025-11-11 15:17:28,244 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.num.users = 10
# 2025-11-11 15:17:28,244 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.windows.minutes = 1,5,25
# 2025-11-11 15:17:28,251 INFO namenode.FSNamesystem: Retry cache on namenode is enabled
# 2025-11-11 15:17:28,251 INFO namenode.FSNamesystem: Retry cache will use 0.03 of total heap and retry cache entry expiry time is 600000 millis
# 2025-11-11 15:17:28,253 INFO util.GSet: Computing capacity for map NameNodeRetryCache
# 2025-11-11 15:17:28,253 INFO util.GSet: VM type       = 64-bit
# 2025-11-11 15:17:28,254 INFO util.GSet: 0.029999999329447746% max memory 3.2 GB = 996.6 KB
# 2025-11-11 15:17:28,254 INFO util.GSet: capacity      = 2^17 = 131072 entries
# 2025-11-11 15:17:28,289 INFO namenode.FSImage: Allocated new BlockPoolId: BP-1109304216-172.28.0.12-1762874248277
# 2025-11-11 15:17:28,319 INFO common.Storage: Storage directory /tmp/hadoop-root/dfs/name has been successfully formatted.
# 2025-11-11 15:17:28,380 INFO namenode.FSImageFormatProtobuf: Saving image file /tmp/hadoop-root/dfs/name/current/fsimage.ckpt_0000000000000000000 using no compression
# 2025-11-11 15:17:28,543 INFO namenode.FSImageFormatProtobuf: Image file /tmp/hadoop-root/dfs/name/current/fsimage.ckpt_0000000000000000000 of size 399 bytes saved in 0 seconds .
# 2025-11-11 15:17:28,569 INFO namenode.NNStorageRetentionManager: Going to retain 1 images with txid >= 0
# 2025-11-11 15:17:28,619 INFO namenode.FSNamesystem: Stopping services started for active state
# 2025-11-11 15:17:28,620 INFO namenode.FSNamesystem: Stopping services started for standby state
# 2025-11-11 15:17:28,626 INFO namenode.FSImage: FSImageSaver clean checkpoint: txid=0 when meet shutdown.
# 2025-11-11 15:17:28,626 INFO namenode.NameNode: SHUTDOWN_MSG:
# /************************************************************
# SHUTDOWN_MSG: Shutting down NameNode at 7dc7ebdfbbd2/172.28.0.12
# ************************************************************/

# %%
# Create folders for namenode/datanode
# !mkdir -p ~/hdfs/namenode ~/hdfs/datanode

# Edit core-site.xml and hdfs-site.xml to use local paths
core_site = """
<configuration>
 <property>
   <name>fs.defaultFS</name>
   <value>hdfs://localhost:9000</value>
 </property>
</configuration>
"""
with open("/usr/local/hadoop/etc/hadoop/core-site.xml", "w") as f:
    f.write(core_site)

hdfs_site = """
<configuration>
 <property>
   <name>dfs.namenode.name.dir</name>
   <value>file:///root/hdfs/namenode</value>
 </property>
 <property>
   <name>dfs.datanode.data.dir</name>
   <value>file:///root/hdfs/datanode</value>
 </property>
 <property>
   <name>dfs.replication</name>
   <value>1</value>
 </property>
</configuration>
"""
with open("/usr/local/hadoop/etc/hadoop/hdfs-site.xml", "w") as f:
    f.write(hdfs_site)

# %%
# Start HDFS (namenode + datanode)
# !hdfs --daemon start namenode
# !hdfs --daemon start datanode

# Create a directory in HDFS
# !hdfs dfs -mkdir /mydata

# Create sample local text files (for upload & testing)
# !echo "This is the first Hadoop sample file." > localfile1.txt
# !echo "This is another sample text file for HDFS operations." > localfile2.txt

# Upload local file to HDFS
# !hdfs dfs -put localfile1.txt /mydata/

# Verify uploaded file
# !hdfs dfs -ls /mydata

# Copy file inside HDFS
# !hdfs dfs -cp /mydata/localfile1.txt /mydata/localfile_copy.txt

# Move file within HDFS
# !hdfs dfs -mv /mydata/localfile_copy.txt /mydata/movedfile.txt

# Download file from HDFS to local system
# !hdfs dfs -get /mydata/movedfile.txt downloaded.txt

# Display downloaded file content
# !cat downloaded.txt

# Remove a file from HDFS
# !hdfs dfs -rm /mydata/movedfile.txt

# Remove the directory completely
# !hdfs dfs -rm -r /mydata
# Out:
# mkdir: Call From 7dc7ebdfbbd2/172.28.0.12 to localhost:9000 failed on connection exception: java.net.ConnectException: Connection refused; For more details see:  http://wiki.apache.org/hadoop/ConnectionRefused
# put: Call From 7dc7ebdfbbd2/172.28.0.12 to localhost:9000 failed on connection exception: java.net.ConnectException: Connection refused; For more details see:  http://wiki.apache.org/hadoop/ConnectionRefused
# ls: Call From 7dc7ebdfbbd2/172.28.0.12 to localhost:9000 failed on connection exception: java.net.ConnectException: Connection refused; For more details see:  http://wiki.apache.org/hadoop/ConnectionRefused
# cp: Call From 7dc7ebdfbbd2/172.28.0.12 to localhost:9000 failed on connection exception: java.net.ConnectException: Connection refused; For more details see:  http://wiki.apache.org/hadoop/ConnectionRefused
# mv: Call From 7dc7ebdfbbd2/172.28.0.12 to localhost:9000 failed on connection exception: java.net.ConnectException: Connection refused; For more details see:  http://wiki.apache.org/hadoop/ConnectionRefused
# get: Call From 7dc7ebdfbbd2/172.28.0.12 to localhost:9000 failed on connection exception: java.net.ConnectException: Connection refused; For more details see:  http://wiki.apache.org/hadoop/ConnectionRefused
# cat: downloaded.txt: No such file or directory
# rm: Call From 7dc7ebdfbbd2/172.28.0.12 to localhost:9000 failed on connection exception: java.net.ConnectException: Connection refused; For more details see:  http://wiki.apache.org/hadoop/ConnectionRefused
# rm: Call From 7dc7ebdfbbd2/172.28.0.12 to localhost:9000 failed on connection exception: java.net.ConnectException: Connection refused; For more details see:  http://wiki.apache.org/hadoop/ConnectionRefused

# %%
# !hdfs --daemon stop namenode
# !hdfs --daemon stop datanode
