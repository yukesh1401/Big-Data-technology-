# %%
# Install Java (required by Hadoop)
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null

# Download Hadoop 3.3.6 (latest stable)
# !wget -q https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# !tar -xzf hadoop-3.3.6.tar.gz
# !mv hadoop-3.3.6 /usr/local/hadoop

# %%
import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["HADOOP_HOME"] = "/usr/local/hadoop"
os.environ["PATH"] += ":/usr/local/hadoop/bin:/usr/local/hadoop/sbin"

# %%
# !hadoop version
# Out:
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /usr/local/hadoop/share/hadoop/common/hadoop-common-3.3.6.jar

# %%
# %%writefile input.txt
# Hadoop MapReduce is a programming model
# for processing large data sets
# with a distributed algorithm
# on a cluster
# MapReduce programs are written in various languages
# Out:
# Writing input.txt

# %%
# %%writefile mapper.py
#!/usr/bin/env python3
import sys
for line in sys.stdin:
    for word in line.strip().split():
        print(f"{word.lower()}\t1")
# Out:
# Writing mapper.py

# %%
# %%writefile reducer.py
#!/usr/bin/env python3
import sys
from itertools import groupby
from operator import itemgetter

data = (line.strip().split("\t") for line in sys.stdin)
for word, group in groupby(sorted(data, key=itemgetter(0)), key=itemgetter(0)):
    total = sum(int(count) for _, count in group)
    print(f"{word}\t{total}")
# Out:
# Writing reducer.py

# %%
# !chmod +x mapper.py reducer.py

# %%
# !hdfs namenode -format
# !start-dfs.sh
# !hadoop fs -mkdir /input
# !hadoop fs -put input.txt /input
# !hadoop fs -ls /input
# Out:
# WARNING: /usr/local/hadoop/logs does not exist. Creating.
# 2025-10-15 11:21:15,771 INFO namenode.NameNode: STARTUP_MSG:
# /************************************************************
# STARTUP_MSG: Starting NameNode
# STARTUP_MSG:   host = 5a853759c36f/172.28.0.12
# STARTUP_MSG:   args = [-format]
# STARTUP_MSG:   version = 3.3.6
# STARTUP_MSG:   classpath = /usr/local/hadoop/etc/hadoop:/usr/local/hadoop/share/hadoop/common/lib/jetty-util-9.4.51.v20230217.jar:/usr/local/hadoop/share/hadoop/common/lib/jetty-security-9.4.51.v20230217.jar:/usr/local/hadoop/share/hadoop/common/lib/failureaccess-1.0.jar:/usr/local/hadoop/share/hadoop/common/lib/jackson-core-asl-1.9.13.jar:/usr/local/hadoop/share/hadoop/common/lib/metrics-core-3.2.4.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-codec-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-codec-smtp-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/guava-27.0-jre.jar:/usr/local/hadoop/share/hadoop/common/lib/j2objc-annotations-1.1.jar:/usr/local/hadoop/share/hadoop/common/lib/snappy-java-1.1.8.2.jar:/usr/local/hadoop/share/hadoop/common/lib/checker-qual-2.5.2.jar:/usr/local/hadoop/share/hadoop/common/lib/kerb-crypto-1.0.1.jar:/usr/local/hadoop/share/hadoop/common/lib/kerby-pkix-1.0.1.jar:/usr/local/hadoop/share/hadoop/common/lib/jersey-core-1.19.4.jar:/usr/local/hadoop/share/hadoop/common/lib/jaxb-api-2.2.11.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-all-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-transport-native-kqueue-4.1.89.Final-osx-x86_64.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-codec-xml-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/animal-sniffer-annotations-1.17.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-daemon-1.0.13.jar:/usr/local/hadoop/share/hadoop/common/lib/jettison-1.5.4.jar:/usr/local/hadoop/share/hadoop/common/lib/jetty-server-9.4.51.v20230217.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-codec-mqtt-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-cli-1.2.jar:/usr/local/hadoop/share/hadoop/common/lib/slf4j-api-1.7.36.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-resolver-dns-native-macos-4.1.89.Final-osx-aarch_64.jar:/usr/local/hadoop/share/hadoop/common/lib/nimbus-jose-jwt-9.8.1.jar:/usr/local/hadoop/share/hadoop/common/lib/kerb-identity-1.0.1.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-transport-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-math3-3.1.1.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-beanutils-1.9.4.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-collections-3.2.2.jar:/usr/local/hadoop/share/hadoop/common/lib/curator-framework-5.2.0.jar:/usr/local/hadoop/share/hadoop/common/lib/curator-client-5.2.0.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-codec-stomp-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-transport-rxtx-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-lang3-3.12.0.jar:/usr/local/hadoop/share/hadoop/common/lib/avro-1.7.7.jar:/usr/local/hadoop/share/hadoop/common/lib/jackson-core-2.12.7.jar:/usr/local/hadoop/share/hadoop/common/lib/kerby-util-1.0.1.jar:/usr/local/hadoop/share/hadoop/common/lib/jcip-annotations-1.0-1.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-codec-http-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-transport-native-unix-common-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/jaxb-impl-2.2.3-1.jar:/usr/local/hadoop/share/hadoop/common/lib/netty-resolver-dns-4.1.89.Final.jar:/usr/local/hadoop/share/hadoop/common/lib/hadoop-auth-3.3.6.jar:/usr/local/hadoop/share/hadoop/common/lib/jsr305-3.0.2.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-io-2.8.0.jar:/usr/local/hadoop/share/hadoop/common/lib/jsr311-api-1.1.1.jar:/usr/local/hadoop/share/hadoop/common/lib/hadoop-annotations-3.3.6.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-text-1.10.0.jar:/usr/local/hadoop/share/hadoop/common/lib/jackson-databind-2.12.7.1.jar:/usr/local/hadoop/share/hadoop/common/lib/commons-codec-1.15.jar:/usr/local/hadoop/share/hadoop/common/lib/jetty-xml-9.4.51.v20230217.jar:/usr/local/hadoop/share/hadoop/common/lib/jul-to-slf4j-1.7.36.jar:/usr/local/hadoop/share/hadoop/common/lib/audience-annotations-0.5.0.jar:/usr/local/hadoop/s ...
# STARTUP_MSG:   build = https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c; compiled by 'ubuntu' on 2023-06-18T08:22Z
# STARTUP_MSG:   java = 11.0.28
# ************************************************************/
# 2025-10-15 11:21:15,816 INFO namenode.NameNode: registered UNIX signal handlers for [TERM, HUP, INT]
# 2025-10-15 11:21:16,056 INFO namenode.NameNode: createNameNode [-format]
# 2025-10-15 11:21:17,280 INFO namenode.NameNode: Formatting using clusterid: CID-630023f4-65f1-4330-ba22-e224e54aca77
# 2025-10-15 11:21:17,364 INFO namenode.FSEditLog: Edit logging is async:true
# 2025-10-15 11:21:17,434 INFO namenode.FSNamesystem: KeyProvider: null
# 2025-10-15 11:21:17,439 INFO namenode.FSNamesystem: fsLock is fair: true
# 2025-10-15 11:21:17,439 INFO namenode.FSNamesystem: Detailed lock hold time metrics enabled: false
# 2025-10-15 11:21:17,498 INFO namenode.FSNamesystem: fsOwner                = root (auth:SIMPLE)
# 2025-10-15 11:21:17,498 INFO namenode.FSNamesystem: supergroup             = supergroup
# 2025-10-15 11:21:17,498 INFO namenode.FSNamesystem: isPermissionEnabled    = true
# 2025-10-15 11:21:17,498 INFO namenode.FSNamesystem: isStoragePolicyEnabled = true
# 2025-10-15 11:21:17,498 INFO namenode.FSNamesystem: HA Enabled: false
# 2025-10-15 11:21:17,564 INFO common.Util: dfs.datanode.fileio.profiling.sampling.percentage set to 0. Disabling file IO profiling
# 2025-10-15 11:21:17,773 INFO blockmanagement.DatanodeManager: dfs.block.invalidate.limit : configured=1000, counted=60, effected=1000
# 2025-10-15 11:21:17,773 INFO blockmanagement.DatanodeManager: dfs.namenode.datanode.registration.ip-hostname-check=true
# 2025-10-15 11:21:17,778 INFO blockmanagement.BlockManager: dfs.namenode.startup.delay.block.deletion.sec is set to 000:00:00:00.000
# 2025-10-15 11:21:17,778 INFO blockmanagement.BlockManager: The block deletion will start around 2025 Oct 15 11:21:17
# 2025-10-15 11:21:17,781 INFO util.GSet: Computing capacity for map BlocksMap
# 2025-10-15 11:21:17,781 INFO util.GSet: VM type       = 64-bit
# 2025-10-15 11:21:17,783 INFO util.GSet: 2.0% max memory 3.2 GB = 64.9 MB
# 2025-10-15 11:21:17,784 INFO util.GSet: capacity      = 2^23 = 8388608 entries
# 2025-10-15 11:21:17,818 INFO blockmanagement.BlockManager: Storage policy satisfier is disabled
# 2025-10-15 11:21:17,818 INFO blockmanagement.BlockManager: dfs.block.access.token.enable = false
# 2025-10-15 11:21:17,827 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.threshold-pct = 0.999
# 2025-10-15 11:21:17,827 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.min.datanodes = 0
# 2025-10-15 11:21:17,827 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.extension = 30000
# 2025-10-15 11:21:17,828 INFO blockmanagement.BlockManager: defaultReplication         = 3
# 2025-10-15 11:21:17,829 INFO blockmanagement.BlockManager: maxReplication             = 512
# 2025-10-15 11:21:17,829 INFO blockmanagement.BlockManager: minReplication             = 1
# 2025-10-15 11:21:17,829 INFO blockmanagement.BlockManager: maxReplicationStreams      = 2
# 2025-10-15 11:21:17,829 INFO blockmanagement.BlockManager: redundancyRecheckInterval  = 3000ms
# 2025-10-15 11:21:17,829 INFO blockmanagement.BlockManager: encryptDataTransfer        = false
# 2025-10-15 11:21:17,829 INFO blockmanagement.BlockManager: maxNumBlocksToLog          = 1000
# 2025-10-15 11:21:17,876 INFO namenode.FSDirectory: GLOBAL serial map: bits=29 maxEntries=536870911
# 2025-10-15 11:21:17,876 INFO namenode.FSDirectory: USER serial map: bits=24 maxEntries=16777215
# 2025-10-15 11:21:17,876 INFO namenode.FSDirectory: GROUP serial map: bits=24 maxEntries=16777215
# 2025-10-15 11:21:17,876 INFO namenode.FSDirectory: XATTR serial map: bits=24 maxEntries=16777215
# 2025-10-15 11:21:17,898 INFO util.GSet: Computing capacity for map INodeMap
# 2025-10-15 11:21:17,898 INFO util.GSet: VM type       = 64-bit
# 2025-10-15 11:21:17,899 INFO util.GSet: 1.0% max memory 3.2 GB = 32.4 MB
# 2025-10-15 11:21:17,899 INFO util.GSet: capacity      = 2^22 = 4194304 entries
# 2025-10-15 11:21:17,915 INFO namenode.FSDirectory: ACLs enabled? true
# 2025-10-15 11:21:17,915 INFO namenode.FSDirectory: POSIX ACL inheritance enabled? true
# 2025-10-15 11:21:17,915 INFO namenode.FSDirectory: XAttrs enabled? true
# 2025-10-15 11:21:17,915 INFO namenode.NameNode: Caching file names occurring more than 10 times
# 2025-10-15 11:21:17,921 INFO snapshot.SnapshotManager: Loaded config captureOpenFiles: false, skipCaptureAccessTimeOnlyChange: false, snapshotDiffAllowSnapRootDescendant: true, maxSnapshotLimit: 65536
# 2025-10-15 11:21:17,923 INFO snapshot.SnapshotManager: SkipList is disabled
# 2025-10-15 11:21:17,928 INFO util.GSet: Computing capacity for map cachedBlocks
# 2025-10-15 11:21:17,929 INFO util.GSet: VM type       = 64-bit
# 2025-10-15 11:21:17,929 INFO util.GSet: 0.25% max memory 3.2 GB = 8.1 MB
# 2025-10-15 11:21:17,929 INFO util.GSet: capacity      = 2^20 = 1048576 entries
# 2025-10-15 11:21:17,944 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.window.num.buckets = 10
# 2025-10-15 11:21:17,944 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.num.users = 10
# 2025-10-15 11:21:17,944 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.windows.minutes = 1,5,25
# 2025-10-15 11:21:17,951 INFO namenode.FSNamesystem: Retry cache on namenode is enabled
# 2025-10-15 11:21:17,951 INFO namenode.FSNamesystem: Retry cache will use 0.03 of total heap and retry cache entry expiry time is 600000 millis
# 2025-10-15 11:21:17,953 INFO util.GSet: Computing capacity for map NameNodeRetryCache
# 2025-10-15 11:21:17,954 INFO util.GSet: VM type       = 64-bit
# 2025-10-15 11:21:17,954 INFO util.GSet: 0.029999999329447746% max memory 3.2 GB = 996.6 KB
# 2025-10-15 11:21:17,954 INFO util.GSet: capacity      = 2^17 = 131072 entries
# 2025-10-15 11:21:17,993 INFO namenode.FSImage: Allocated new BlockPoolId: BP-1753493698-172.28.0.12-1760527277982
# 2025-10-15 11:21:18,052 INFO common.Storage: Storage directory /tmp/hadoop-root/dfs/name has been successfully formatted.
# 2025-10-15 11:21:18,123 INFO namenode.FSImageFormatProtobuf: Saving image file /tmp/hadoop-root/dfs/name/current/fsimage.ckpt_0000000000000000000 using no compression
# 2025-10-15 11:21:18,319 INFO namenode.FSImageFormatProtobuf: Image file /tmp/hadoop-root/dfs/name/current/fsimage.ckpt_0000000000000000000 of size 399 bytes saved in 0 seconds .
# 2025-10-15 11:21:18,348 INFO namenode.NNStorageRetentionManager: Going to retain 1 images with txid >= 0
# 2025-10-15 11:21:18,412 INFO namenode.FSNamesystem: Stopping services started for active state
# 2025-10-15 11:21:18,413 INFO namenode.FSNamesystem: Stopping services started for standby state
# 2025-10-15 11:21:18,419 INFO namenode.FSImage: FSImageSaver clean checkpoint: txid=0 when meet shutdown.
# 2025-10-15 11:21:18,423 INFO namenode.NameNode: SHUTDOWN_MSG:
# /************************************************************
# SHUTDOWN_MSG: Shutting down NameNode at 5a853759c36f/172.28.0.12
# ************************************************************/
# Starting namenodes on [5a853759c36f]
# ERROR: Attempting to operate on hdfs namenode as root
# ERROR: but there is no HDFS_NAMENODE_USER defined. Aborting operation.
# Starting datanodes
# ERROR: Attempting to operate on hdfs datanode as root
# ERROR: but there is no HDFS_DATANODE_USER defined. Aborting operation.
# Starting secondary namenodes [5a853759c36f]
# ERROR: Attempting to operate on hdfs secondarynamenode as root
# ERROR: but there is no HDFS_SECONDARYNAMENODE_USER defined. Aborting operation.
# Found 1 items
# -rw-r--r--   1 root root        165 2025-10-15 11:21 /input/input.txt

# %%
# !hadoop jar $HADOOP_HOME/share/hadoop/tools/lib/hadoop-streaming-3.3.6.jar \
    -input /input/input.txt \
    -output /output \
    -mapper mapper.py \
    -reducer reducer.py
# Out:
# 2025-10-15 11:21:49,274 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2025-10-15 11:21:49,544 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2025-10-15 11:21:49,545 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2025-10-15 11:21:49,572 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2025-10-15 11:21:49,944 INFO mapred.FileInputFormat: Total input files to process : 1
# 2025-10-15 11:21:49,983 INFO mapreduce.JobSubmitter: number of splits:1
# 2025-10-15 11:21:50,473 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local874769224_0001
# 2025-10-15 11:21:50,473 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2025-10-15 11:21:50,930 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2025-10-15 11:21:50,935 INFO mapreduce.Job: Running job: job_local874769224_0001
# 2025-10-15 11:21:50,943 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2025-10-15 11:21:50,959 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2025-10-15 11:21:50,980 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-10-15 11:21:50,980 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-10-15 11:21:51,064 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2025-10-15 11:21:51,069 INFO mapred.LocalJobRunner: Starting task: attempt_local874769224_0001_m_000000_0
# 2025-10-15 11:21:51,120 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-10-15 11:21:51,121 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-10-15 11:21:51,148 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-10-15 11:21:51,160 INFO mapred.MapTask: Processing split: file:/input/input.txt:0+165
# 2025-10-15 11:21:51,177 INFO mapred.MapTask: numReduceTasks: 1
# 2025-10-15 11:21:51,268 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2025-10-15 11:21:51,268 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2025-10-15 11:21:51,268 INFO mapred.MapTask: soft limit at 83886080
# 2025-10-15 11:21:51,268 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2025-10-15 11:21:51,269 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2025-10-15 11:21:51,273 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2025-10-15 11:21:51,283 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper.py]
# 2025-10-15 11:21:51,289 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2025-10-15 11:21:51,292 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2025-10-15 11:21:51,292 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2025-10-15 11:21:51,293 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2025-10-15 11:21:51,294 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2025-10-15 11:21:51,294 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2025-10-15 11:21:51,296 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2025-10-15 11:21:51,296 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2025-10-15 11:21:51,297 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2025-10-15 11:21:51,297 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2025-10-15 11:21:51,298 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2025-10-15 11:21:51,299 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2025-10-15 11:21:51,332 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-10-15 11:21:51,404 INFO streaming.PipeMapRed: Records R/W=5/1
# 2025-10-15 11:21:51,417 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-10-15 11:21:51,419 INFO streaming.PipeMapRed: mapRedFinished
# 2025-10-15 11:21:51,423 INFO mapred.LocalJobRunner:
# 2025-10-15 11:21:51,423 INFO mapred.MapTask: Starting flush of map output
# 2025-10-15 11:21:51,423 INFO mapred.MapTask: Spilling map output
# 2025-10-15 11:21:51,424 INFO mapred.MapTask: bufstart = 0; bufend = 215; bufvoid = 104857600
# 2025-10-15 11:21:51,424 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214300(104857200); length = 97/6553600
# 2025-10-15 11:21:51,439 INFO mapred.MapTask: Finished spill 0
# 2025-10-15 11:21:51,465 INFO mapred.Task: Task:attempt_local874769224_0001_m_000000_0 is done. And is in the process of committing
# 2025-10-15 11:21:51,472 INFO mapred.LocalJobRunner: Records R/W=5/1
# 2025-10-15 11:21:51,472 INFO mapred.Task: Task 'attempt_local874769224_0001_m_000000_0' done.
# 2025-10-15 11:21:51,483 INFO mapred.Task: Final Counters for attempt_local874769224_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=141576
# 		FILE: Number of bytes written=780298
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=5
# 		Map output records=25
# 		Map output bytes=215
# 		Map output materialized bytes=271
# 		Input split bytes=73
# 		Combine input records=0
# 		Spilled Records=25
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=305135616
# 	File Input Format Counters
# 		Bytes Read=181
# 2025-10-15 11:21:51,483 INFO mapred.LocalJobRunner: Finishing task: attempt_local874769224_0001_m_000000_0
# 2025-10-15 11:21:51,484 INFO mapred.LocalJobRunner: map task executor complete.
# 2025-10-15 11:21:51,489 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2025-10-15 11:21:51,489 INFO mapred.LocalJobRunner: Starting task: attempt_local874769224_0001_r_000000_0
# 2025-10-15 11:21:51,506 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2025-10-15 11:21:51,506 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2025-10-15 11:21:51,506 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2025-10-15 11:21:51,511 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@1ed8adb7
# 2025-10-15 11:21:51,513 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2025-10-15 11:21:51,542 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2381106432, maxSingleShuffleLimit=595276608, mergeThreshold=1571530368, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2025-10-15 11:21:51,545 INFO reduce.EventFetcher: attempt_local874769224_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2025-10-15 11:21:51,590 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local874769224_0001_m_000000_0 decomp: 267 len: 271 to MEMORY
# 2025-10-15 11:21:51,595 INFO reduce.InMemoryMapOutput: Read 267 bytes from map-output for attempt_local874769224_0001_m_000000_0
# 2025-10-15 11:21:51,598 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 267, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->267
# 2025-10-15 11:21:51,602 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2025-10-15 11:21:51,605 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2025-10-15 11:21:51,606 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2025-10-15 11:21:51,621 INFO mapred.Merger: Merging 1 sorted segments
# 2025-10-15 11:21:51,621 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 263 bytes
# 2025-10-15 11:21:51,623 INFO reduce.MergeManagerImpl: Merged 1 segments, 267 bytes to disk to satisfy reduce memory limit
# 2025-10-15 11:21:51,624 INFO reduce.MergeManagerImpl: Merging 1 files, 271 bytes from disk
# 2025-10-15 11:21:51,625 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2025-10-15 11:21:51,625 INFO mapred.Merger: Merging 1 sorted segments
# 2025-10-15 11:21:51,626 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 263 bytes
# 2025-10-15 11:21:51,627 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2025-10-15 11:21:51,633 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./reducer.py]
# 2025-10-15 11:21:51,640 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2025-10-15 11:21:51,646 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2025-10-15 11:21:51,679 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-10-15 11:21:51,682 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2025-10-15 11:21:51,756 INFO streaming.PipeMapRed: Records R/W=25/1
# 2025-10-15 11:21:51,768 INFO streaming.PipeMapRed: MRErrorThread done
# 2025-10-15 11:21:51,769 INFO streaming.PipeMapRed: mapRedFinished
# 2025-10-15 11:21:51,770 INFO mapred.Task: Task:attempt_local874769224_0001_r_000000_0 is done. And is in the process of committing
# 2025-10-15 11:21:51,772 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2025-10-15 11:21:51,772 INFO mapred.Task: Task attempt_local874769224_0001_r_000000_0 is allowed to commit now
# 2025-10-15 11:21:51,775 INFO output.FileOutputCommitter: Saved output of task 'attempt_local874769224_0001_r_000000_0' to file:/output
# 2025-10-15 11:21:51,776 INFO mapred.LocalJobRunner: Records R/W=25/1 > reduce
# 2025-10-15 11:21:51,776 INFO mapred.Task: Task 'attempt_local874769224_0001_r_000000_0' done.
# 2025-10-15 11:21:51,777 INFO mapred.Task: Final Counters for attempt_local874769224_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=142150
# 		FILE: Number of bytes written=780776
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=22
# 		Reduce shuffle bytes=271
# 		Reduce input records=25
# 		Reduce output records=22
# 		Spilled Records=25
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=305135616
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=207
# 2025-10-15 11:21:51,777 INFO mapred.LocalJobRunner: Finishing task: attempt_local874769224_0001_r_000000_0
# 2025-10-15 11:21:51,778 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2025-10-15 11:21:51,959 INFO mapreduce.Job: Job job_local874769224_0001 running in uber mode : false
# 2025-10-15 11:21:51,960 INFO mapreduce.Job:  map 100% reduce 100%
# 2025-10-15 11:21:51,961 INFO mapreduce.Job: Job job_local874769224_0001 completed successfully
# 2025-10-15 11:21:51,971 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=283726
# 		FILE: Number of bytes written=1561074
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=5
# 		Map output records=25
# 		Map output bytes=215
# 		Map output materialized bytes=271
# 		Input split bytes=73
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=22
# 		Reduce shuffle bytes=271
# 		Reduce input records=25
# 		Reduce output records=22
# 		Spilled Records=50
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=610271232
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=181
# 	File Output Format Counters
# 		Bytes Written=207
# 2025-10-15 11:21:51,971 INFO streaming.StreamJob: Output directory: /output

# %%
# !hadoop fs -cat /output/part-00000
# Out:
# a	3
# algorithm	1
# are	1
# cluster	1
# data	1
# distributed	1
# for	1
# hadoop	1
# in	1
# is	1
# languages	1
# large	1
# mapreduce	2
# model	1
# on	1
# processing	1
# programming	1
# programs	1
# sets	1
# various	1
# with	1
# written	1
